# %% [markdown]
# # Dataset Analysis 1: Malaria in Africa (2007-2017)

# %%
# Imports Data Science Libraries
#pip install plotly  #pip install ipykernel  #pip install nbformat
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
# Data Load
df = pd.read_csv('Datasets/AfricaMalaria.csv')
print('Number of rows and columns in the dataset: ', df.shape)
# Out:
# Number of rows and columns in the dataset:  (594, 27)

# %%
# Show column names
# Out:
# Index(['Country Name', 'Year', 'Country Code',
#        'Incidence of malaria (per 1,000 population at risk)',
#        'Malaria cases reported',
#        'Use of insecticide-treated bed nets (% of under-5 population)',
#        'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
#        'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)',
#        'People using safely managed drinking water services (% of population)',
#        'People using safely managed drinking water services, rural (% of rural population)',
#        'People using safely managed drinking water services, urban (% of urban population)',
#        'People using safely managed sanitation services (% of population)',
#        'People using safely managed sanitation services, rural (% of rural population)',
#        'People using safely managed sanitation services, urban  (% of urban population)',
# ...

# %%
# Show the first few rows
# Out:
#    Country Name  Year Country Code  \
# 0       Algeria  2007          DZA
# 1        Angola  2007          AGO
# 2         Benin  2007          BEN
# 3      Botswana  2007          BWA
# 4  Burkina Faso  2007          BFA
#
#    Incidence of malaria (per 1,000 population at risk)  \
# 0                                               0.01
# 1                                             286.72
# 2                                             480.24
# 3                                               1.03
# 4                                             503.80
#
#    Malaria cases reported  \
# 0                    26.0
# 1               1533485.0
# 2                     0.0
# 3                   390.0
# 4                 44246.0
#
#    Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                                NaN
# 1                                               18.0
# 2                                                NaN
# ...

# %%
# Show basic statistical data in the dataframe
# Out:
#               Year  Incidence of malaria (per 1,000 population at risk)  \
# count   594.000000                                         550.000000
# mean   2012.000000                                         190.087491
# std       3.164943                                         163.054527
# min    2007.000000                                           0.000000
# 25%    2009.000000                                          30.857500
# 50%    2012.000000                                         174.775000
# 75%    2015.000000                                         347.637500
# max    2017.000000                                         585.540000
#
#        Malaria cases reported  \
# count            5.500000e+02
# mean             1.068330e+06
# std              2.192802e+06
# min              0.000000e+00
# 25%              2.211750e+03
# 50%              1.130260e+05
# 75%              1.154808e+06
# max              1.682113e+07
#
# ...

# %%
# Remove duplicates if any
# Out:
#      Country Name  Year Country Code  \
# 0         Algeria  2007          DZA
# 1          Angola  2007          AGO
# 2           Benin  2007          BEN
# 3        Botswana  2007          BWA
# 4    Burkina Faso  2007          BFA
# ..            ...   ...          ...
# 589          Togo  2017          TGO
# 590       Tunisia  2017          TUN
# 591        Uganda  2017          UGA
# 592        Zambia  2017          ZMB
# 593      Zimbabwe  2017          ZWE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 0                                                 0.01
# 1                                               286.72
# 2                                               480.24
# 3                                                 1.03
# 4                                               503.80
# ..                                                 ...
# 589                                             278.20
# 590                                                NaN
# ...

# %%
# The info() method to show the datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 27 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   Country Name                                                                             594 non-null    object
#  1   Year                                                                                     594 non-null    int64
#  2   Country Code                                                                             594 non-null    object
#  3   Incidence of malaria (per 1,000 population at risk)                                      550 non-null    float64
#  4   Malaria cases reported                                                                   550 non-null    float64
# ...

# %%
# .isnull().sum() returns the number of missing values in the dataset.
# Out:
# Country Name                                                                                 0
# Year                                                                                         0
# Country Code                                                                                 0
# Incidence of malaria (per 1,000 population at risk)                                         44
# Malaria cases reported                                                                      44
# Use of insecticide-treated bed nets (% of under-5 population)                              462
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    472
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      488
# People using safely managed drinking water services (% of population)                      495
# People using safely managed drinking water services, rural (% of rural population)         506
# ...

# %%
# (Optional) Show a heatmap of the missing values
plt.figure(figsize=(12,2))
sns.heatmap(df.isnull(), cbar=False, cmap='crest', yticklabels=False)
plt.title('Missing values in the dataset')
# Out:
# Text(0.5, 1.0, 'Missing values in the dataset')

# %%
# Identify the columns that require to be removed (due to too many NaN)
# Out:
# ['Use of insecticide-treated bed nets (% of under-5 population)',
#  'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
#  'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)',
#  'People using safely managed drinking water services (% of population)',
#  'People using safely managed drinking water services, rural (% of rural population)',
#  'People using safely managed drinking water services, urban (% of urban population)',
#  'People using safely managed sanitation services (% of population)',
#  'People using safely managed sanitation services, rural (% of rural population)',
#  'People using safely managed sanitation services, urban  (% of urban population)']

# %%
# Remove the columns with more than 60 missing values
# Out:
#    Country Name  Year Country Code  \
# 0       Algeria  2007          DZA
# 1        Angola  2007          AGO
# 2         Benin  2007          BEN
# 3      Botswana  2007          BWA
# 4  Burkina Faso  2007          BFA
#
#    Incidence of malaria (per 1,000 population at risk)  \
# 0                                               0.01
# 1                                             286.72
# 2                                             480.24
# 3                                               1.03
# 4                                             503.80
#
#    Malaria cases reported  Rural population (% of total population)  \
# 0                    26.0                                     34.65
# 1               1533485.0                                     42.48
# 2                     0.0                                     58.44
# 3                   390.0                                     42.07
# 4                 44246.0                                     77.00
#
# ...

# %%
# (Optional) Show the current heatmap of the missing values
plt.figure(figsize=(12,2))
sns.heatmap(df.isnull())
plt.title('Missing values in the dataset after columns removal')
# Out:
# Text(0.5, 1.0, 'Missing values in the dataset after columns removal')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Most reported cases of Malaria: The top 10 African countries
# Out:
#                   Malaria cases reported
# Country Name
# Malawi                        19445640.0
# Angola                        24034182.0
# Tanzania                      24283088.0
# Ghana                         28008309.0
# Nigeria                       40066570.0
# Burundi                       40249714.0
# Uganda                        41126230.0
# Burkina Faso                  41601963.0
# Mozambique                    43984158.0
# Congo, Dem. Rep.              77555524.0

# %%
# barplot for the top 10 most reported cases of Malaria in African countries
# Out:
# <Axes: xlabel='Malaria cases reported'>

# %%
# lineplot for the top 10 most reported cases of Malaria in African countries
# Out:
# <Axes: xlabel='Year', ylabel='Malaria cases reported'>

# %%
# lineplot for the number of reported cases in Kenya
# Out:
# Text(0.5, 1.0, 'Number of reported Malaria cases in Kenya')

# %%
# Twin y axis for lineplots: Urban population growth vs reported cases in Kenya
# Out:
# Text(0.5, 1.0, 'Urban population growth vs reported cases in Kenya')

# %%
# choropleth for Incidence of Malaria at risk
import plotly.express as px
fig = px.choropleth(df, locations=df['Country Code'], color=df['Incidence of malaria (per 1,000 population at risk)'], color_continuous_scale='Blues', locationmode='ISO-3', scope='africa', animation_frame=df['Year'], title="Incidence of Malaria at risk in Africa", labels={'color':'Incidence of Malaria'})
fig.show()

# %%
# choropleth for Malaria Cases Reported by country
fig = px.choropleth(df, locations=df['Country Code'], color=df['Malaria cases reported'], color_continuous_scale='Blues', locationmode='ISO-3', scope='africa', animation_frame=df['Year'], title="Reported Malaria Cases in Africa", labels={'color':'number of Malaria cases'})
fig.show()

# %%
# Linear model plot for Incidence of malaria vs year in Kenya

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Problems encountered:
# * Many missing values (NaN) present in this dataset including those in the target column ['Malaria cases reported'].
# * Removing the columns with missing values will also remove most of the existing values.
# * Removing the rows with missing values will result in unequal number of rows in the X and y arrays. Thus, unable to data split.
#
# ### Approach:
# * For the target column (y array), replace the missing values with the mean value. Alternative filling options include 0, mode or median.
# * For the training X array data (X_train & X_test), imputate to replace the missing values with the mean value.

# %%
# Import sklearn libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.impute import SimpleImputer

# %%
# Identify the columns that require to be removed (due to too many NaN)
df.isnull().sum()
# Out:
# Country Name                                                                           0
# Year                                                                                   0
# Country Code                                                                           0
# Incidence of malaria (per 1,000 population at risk)                                   44
# Malaria cases reported                                                                44
# Rural population (% of total population)                                               6
# Rural population growth (annual %)                                                     6
# Urban population (% of total population)                                               6
# Urban population growth (annual %)                                                     6
# People using at least basic drinking water services (% of population)                  6
# ...

# %%
# Remove the columns with more than 60 missing values
cc1 = [col for col in df.columns if df[col].isnull().sum()>60]
df = df.drop(columns=cc1)
df.isnull().sum()
# Out:
# Country Name                                                                           0
# Year                                                                                   0
# Country Code                                                                           0
# Incidence of malaria (per 1,000 population at risk)                                   44
# Malaria cases reported                                                                44
# Rural population (% of total population)                                               6
# Rural population growth (annual %)                                                     6
# Urban population (% of total population)                                               6
# Urban population growth (annual %)                                                     6
# People using at least basic drinking water services (% of population)                  6
# ...

# %%
# Create a target column (the y array) and fill the missing values with the mean value
y = df['Malaria cases reported'].fillna(df['Malaria cases reported'].mean())
y.isnull().sum()
# Out:
# 0

# %%
# Separate the y array from numerical predictors (X array)
# Note: The missing values in the X array will be imputed in the next stage. X.isnull().sum()
a = df.drop('Malaria cases reported', axis=1)
X = a.select_dtypes(exclude=['object'])

# Data Split: Train-Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
X_train.head()
# Out:
#      Year  Incidence of malaria (per 1,000 population at risk)  \
# 186  2010                                             134.37
# 355  2013                                             452.82
# 376  2013                                             225.77
# 140  2009                                              31.64
# 580  2017                                              10.81
#
#      Rural population (% of total population)  \
# 186                                     59.89
# 355                                     61.60
# 376                                     59.14
# 140                                     54.31
# 580                                     28.03
#
#      Rural population growth (annual %)  \
# 186                                1.92
# 355                                1.61
# 376                                2.28
# 140                                1.27
# 580                               -1.20
#
#      Urban population (% of total population)  \
# ...

# %%
# Create two new columns to replace X_train and X_test. All the missing values have now been placed by mean values.
# Imputation
imputer = SimpleImputer(strategy='mean')
imX_train = pd.DataFrame(imputer.fit_transform(X_train))
imX_test = pd.DataFrame(imputer.transform(X_test))

# Imputation swap the imputed columns into the X_train & X_test
imX_train.columns = X_train.columns
imX_test.columns = X_test.columns

imX_train.isnull().sum()
# Out:
# Year                                                                                  0
# Incidence of malaria (per 1,000 population at risk)                                   0
# Rural population (% of total population)                                              0
# Rural population growth (annual %)                                                    0
# Urban population (% of total population)                                              0
# Urban population growth (annual %)                                                    0
# People using at least basic drinking water services (% of population)                 0
# People using at least basic drinking water services, rural (% of rural population)    0
# People using at least basic drinking water services, urban (% of urban population)    0
# People using at least basic sanitation services (% of population)                     0
# People using at least basic sanitation services, rural (% of rural population)        0
# ...

# %% [markdown]
# ___
# ## Linear Regression

# %%
# Model Training
lm = LinearRegression()
lm.fit(imX_train, y_train)
# Out:
# LinearRegression()

# %%
# Prediction & Evaluation
lrp = lm.predict(imX_test)
print('LR MAE:', metrics.mean_absolute_error(y_test, lrp))
print('LR MSE:', metrics.mean_squared_error(y_test, lrp))
print('LR RMSE:', np.sqrt(metrics.mean_squared_error(y_test, lrp)))
print('LR R2 Score:', lm.score(imX_test,y_test))
# Out:
# LR MAE: 974330.7373748684
# LR MSE: 1655365711205.2449
# LR RMSE: 1286610.1628718954
# LR R2 Score: 0.3295391375487887

# %%
# Optional scatterplot and residual histogram
plt.scatter(y_test, lrp)
sns.displot(y_test-lrp)

# %% [markdown]
# ___
# ## Gradient Boosting Regressor

# %%
# Model Training
gbr = GradientBoostingRegressor(random_state=0)
gbr.fit(imX_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=0)

# %%
# Prediction & Evaluation
gbrp = gbr.predict(imX_test)
print('GBR MAE:', metrics.mean_absolute_error(y_test, gbrp))
print('GBR MSE:', metrics.mean_squared_error(y_test, gbrp))
print('GBR RMSE:', np.sqrt(metrics.mean_squared_error(y_test, gbrp)))
print('GBR R2 Score:', gbr.score(imX_test,y_test))
# Out:
# GBR MAE: 548340.2283151058
# GBR MSE: 1052090394071.9078
# GBR RMSE: 1025714.5772932682
# GBR R2 Score: 0.5738793982433608

# %%
# Optional scatterplot and residual histogram
plt.scatter(y_test, gbrp)
sns.displot(y_test-gbrp)

# %% [markdown]
# ___

# %%
# Optional tool: To check whether the X and the y arrays have the same number of rows
print(X.shape)
print(y.shape)

if X.shape[0] != y.shape[0]:
    print("X and y rows are mismatched, check dataset again")
# Out:
# (594, 14)
# (594,)
