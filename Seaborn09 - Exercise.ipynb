# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# ___
# ## Libraries Import & Data Load
# * Dataset type: Seaborn built-in dataset - titanic

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('whitegrid')
ti = sns.load_dataset('titanic')
ti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ___
# ## Exercises
# * Recreate the plots below using the titanic dataframe.

# %%
#1. Observe the correct plot image shown below and place code here to replicate the same display.

# %%
# DO NOT PLACE CODE HERE

# %% [markdown]
# ___

# %%
#2. Observe the correct plot image shown below and place code here to replicate the same display.

# %%
# DO NOT PLACE CODE HERE

# %% [markdown]
# ___

# %%
#3. Observe the correct plot image shown below and place code here to replicate the same display.
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
# DO NOT PLACE CODE HERE
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %% [markdown]
# ___

# %%
#4. Observe the correct plot image shown below and place code here to replicate the same display.
# Hint: Use move_legend()

# %%
# DO NOT PLACE CODE HERE

# %% [markdown]
# ___

# %%
#5. Observe the correct plot image shown below and place code here to replicate the same display.

# %%
# DO NOT PLACE CODE HERE
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ___

# %%
#6. Observe the correct plot image shown below and place code here to replicate the same display.

# %%
# DO NOT PLACE CODE HERE
# Out:
# Text(0.5, 1.0, 'Titanic dataset correlation chart')

# %% [markdown]
# ___

# %%
#7. Observe the correct plot image shown below and place code here to replicate the same display.
# Hints: use FacetGrid; multiple possible solutions

# %%
# DO NOT PLACE CODE HERE

# %% [markdown]
# ___
